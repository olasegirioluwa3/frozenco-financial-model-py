# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(10)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
filtN = (df['Country'] == 'Nigeria')
nigeria_df = df.loc[filtN]

# %%
nigeria_df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 205         I am not primarily a developer, but I write co...      Yes
# 348                            I am a developer by profession      Yes
# 365                               I code primarily as a hobby      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 205                                   Less than once per year
# 348                                   Less than once per year
# 365         Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 205         OSS is, on average, of HIGHER quality than pro...
# 348         OSS is, on average, of LOWER quality than prop...
# 365         The quality of OSS and closed source software ...
#
#                                                    Employment  Country  \
# Respondent
# ...

# %%
nigeria_df.to_csv('data/modified_nigeria.csv')

# %%
filt2 = nigeria_df['Gender'] == 'Man'
nigeria_df[filt2]['Age'].min()
# Out:
# 15.0

# %%
filt3 = india_df['Gender'] == 'Man'
india_df[filt3]['Age'].min()
# Out:
# 1.0

# %%
# !pip install xlwt openpyxl xlrd

# %%
nigeria_df.to_excel('data/modified_nigeria2.xlsx')

# %%
excel = pd.read_excel('data/modified_nigeria.xlsx', index_col='Respondent')

# %%
excel
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 205         I am not primarily a developer, but I write co...      Yes
# 348                            I am a developer by profession      Yes
# 365                               I code primarily as a hobby      Yes
# 688                            I am a developer by profession      Yes
# 885                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 88812                          I am a developer by profession      Yes
# 88821                  I am a student who is learning to code       No
# 76960                                                     NaN       No
# 79616                                                     NaN       No
# 86806                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
nigeria_df.to_json('data/modified_nigeria.json', orient='records', lines=True)

# %%
my_json = pd.read_json('data/modified_nigeria.json', orient='records', lines=True)

# %%
my_json
# Out:
#                                             MainBranch Hobbyist  \
# 0    I am not primarily a developer, but I write co...      Yes
# 1                       I am a developer by profession      Yes
# 2                          I code primarily as a hobby      Yes
# 3                       I am a developer by profession      Yes
# 4                       I am a developer by profession      Yes
# ..                                                 ...      ...
# 517                     I am a developer by profession      Yes
# 518             I am a student who is learning to code       No
# 519                                               None       No
# 520                                               None       No
# 521                                               None      Yes
#
#                                            OpenSourcer  \
# 0                              Less than once per year
# 1                              Less than once per year
# ...

# %%
# !pip install SQLAlchemy psycopg2-binary
# Out:
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      -                                        0.0/1.2 MB 660.6 kB/s eta 0:00:02
#      -                                        0.0/1.2 MB 660.6 kB/s eta 0:00:02
#      --                                       0.1/1.2 MB 573.4 kB/s eta 0:00:02
#      ---                                      0.1/1.2 MB 544.7 kB/s eta 0:00:02
#      ----                                     0.1/1.2 MB 514.3 kB/s eta 0:00:03
#      -----                                    0.2/1.2 MB 517.2 kB/s eta 0:00:02
#      ------                                   0.2/1.2 MB 535.8 kB/s eta 0:00:02
#      -------                                  0.2/1.2 MB 509.6 kB/s eta 0:00:02
#      --------                                 0.3/1.2 MB 506.7 kB/s eta 0:00:02
#      ----------                               0.3/1.2 MB 524.2 kB/s eta 0:00:02
#      -----------                              0.3/1.2 MB 534.4 kB/s eta 0:00:02
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('mysql://root:mysql@localhost:80/early_production_db')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 engine = create_engine('mysql://root:mysql@localhost:80/early_production_db')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\sqlalchemy\engine\create.py:601, in create_engine(url, **kwargs)
#     599         if k in kwargs:
# ...
