# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(10)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# ...

# %%
df.tail(8)
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 88182             NaN      Yes
# 88212             NaN       No
# 88282             NaN      Yes
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 88182                              Once a month or more often
# 88212                                 Less than once per year
# 88282                              Once a month or more often
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# 88816                                                   Never
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.iloc[0, 1]
# Out:
# 'Yes'

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True, ascending=False)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object>

# %%
df['Hobbyist'][1]
# Out:
# 'Yes'

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
countries = ['United States', 'India', 'United Kindom', 'Germany']
filt = df['Country'].isin(countries)

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filtLang = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filtLang, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.loc[filtLang]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df.sort_values(by=['Country','SalaryUSD'], ascending=[True,False], inplace=True)
filtSort = df.sort_values(by=['Country','SalaryUSD'], ascending=[True,False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(10)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10, 'SalaryUSD').head(10)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 722                            I am a developer by profession     False
# 28638                          I am a developer by profession      True
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
df['Student'].count()
# Out:
# 87014

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Nigeria').head()
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 31220       I am a developer by profession      True
# 45962       I am a developer by profession      True
# 71883       I am a developer by profession      True
# 47770       I am a developer by profession      True
# 1015        I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 31220                                                   Never
# 45962                                 Less than once per year
# 71883                                                   Never
# 47770       Less than once a month but more than once per ...
# 1015        Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 31220       The quality of OSS and closed source software ...
# 45962       The quality of OSS and closed source software ...
# ...

# %%
filtCountry = df['Country'] == 'United States'
df.loc[filtCountry]['SocialMedia'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Respondent
# 58       I don't use social media
# 102      I don't use social media
# 166                       Twitter
# 436                        Reddit
# 452                      Facebook
#                    ...
# 78292    I don't use social media
# 82717                    Facebook
# 83397                         NaN
# 85642                         NaN
# 88282    I don't use social media
# Name: SocialMedia, Length: 20949, dtype: object>

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
#filtCountry = df['Çountry'] == 'India'
df.loc[filtCountry]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 10083

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.value_counts(normalize=True))
# Out:
# Country
# Afghanistan  HTML/CSS;JavaScript;PHP;SQL                               0.076923
#              Python                                                    0.051282
#              HTML/CSS;Java;JavaScript;PHP;Python;SQL                   0.051282
#              HTML/CSS;Java;PHP;SQL                                     0.051282
#              Assembly;C;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript    0.025641
#                                                                          ...
# Zimbabwe     C;C++;C#;HTML/CSS;Java;JavaScript;PHP;SQL;VBA             0.025641
#              Assembly;C;C++;C#;HTML/CSS;JavaScript;Python;VBA          0.025641
#              Assembly;HTML/CSS;JavaScript;TypeScript                   0.025641
#              C;C++;HTML/CSS;Python                                     0.025641
#              Assembly;C++;C#;HTML/CSS;Java;JavaScript;PHP;VBA          0.025641
# Name: LanguageWorkedWith, Length: 48114, dtype: float64

# %%
country_resp = df['Country'].value_counts()
country_resp
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_resp, country_uses_python], sort=False)
python_df
# Out:
# Country
# United States                           20949
# India                                    9061
# Germany                                  5866
# United Kingdom                           5737
# Canada                                   3395
#                                         ...
# Venezuela, Bolivarian Republic of...       28
# Viet Nam                                   78
# Yemen                                       3
# Zambia                                      4
# Zimbabwe                                   14
# Length: 358, dtype: int64

# %%
 df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '1', nan,
#        'More than 50 years', '20', '9', '5', '8', '31', '28', '15', '13',
#        '12', '17', '18', '21', '35', '14', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '32',
#        '26', '38', '44', '41', '45', '37', '47', '42', '46', '48', '50',
#        '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
